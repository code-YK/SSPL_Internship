# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path(r"e:\SSPL_Internship_Repo\Jan_05_26\Trip_Event_Planner")
if str(PROJECT_ROOT) not in sys.path:
    sys.path.append(str(PROJECT_ROOT))

print("Project root:", PROJECT_ROOT)
# Out:
# Project root: e:\SSPL_Internship_Repo\Jan_05_26\Trip_Event_Planner

# %%
from graph import trip_event_graph
# Out:
# 2026-01-08 17:15:53 || INFO || llm || Initializing Groq LLM
# 2026-01-08 17:15:54 || INFO || llm || Groq LLM initialized | model=llama-3.3-70b-versatile | temperature=0.3

# %%
from IPython.display import Image, display
display(Image(trip_event_graph.get_graph().draw_mermaid_png()))
