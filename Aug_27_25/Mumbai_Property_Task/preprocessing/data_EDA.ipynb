# %% [markdown]
# ## Mumbai Property Dataset
# - Target variable : Super Buildup rate
#
# ### In this file following stuffs are implemented :
# - Data understanding (Domain knownledge)
# - Data cleaning
# - EDA
# - Cleaned dataset is imported into new csv file

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('./mumbai_property_data_with_TS.csv')

# %%
df.head()
# Out:
#    ID Property Type    Address Area                       Amenities  \
# 0   1   Residential   Borivali East              Playground, Garden
# 1   2   Residential   Borivali East  Playground, Parking, Gym, Lift
# 2   3   Residential      Malad East           Garden, Swimming Pool
# 3   4   Residential            Juhu        Playground, Garden, Lift
# 4   5   Residential  Santacruz West                     Gym, Garden
#
#    Property Age  Carpet Area (sq.ft.)  Super Buildup Rate (per sq.ft.)  \
# 0            15                   709                          21381.6
# 1             6                  1110                          27342.0
# 2            10                  1130                          26906.0
# 3             8                  2166                          57346.0
# 4             3                  2453                          52827.0
#
#    Built-Up Area (sq.ft.)  Area as per Approved Plan (sq.ft.)  \
# 0                     672                                 643
# 1                    1089                                1067
# 2                    1102                                1072
# 3                    2120                                2096
# 4                    2419                                2403
#
#    Valuation Area (sq.ft.)  ...  Last Sale Price (per sq.ft.)  \
# 0                      672  ...                         35606
# 1                     1089  ...                         32697
# 2                     1102  ...                         24754
# 3                     2120  ...                         53333
# 4                     2419  ...                         52791
#
#    Last to Last Sale Price (per sq.ft.)  Last Sale Year  \
# 0                                 35606            2011
# 1                                 32697            2020
# 2                                 24754            2016
# 3                                 49114            2020
# 4                                 52791            2023
#
#    Last to Last Sale Year           Property Name Rate 2021 (per sq.ft.)  \
# 0                    2011               River Hts                  18570
# 1                    2020             Moon Hights                  27538
# 2                    2016            Golden Vilas                  24236
# 3                    2018              Green Gdns                  50907
# 4                    2023  Santacruz West Res Apt                  54514
#
#   Rate 2022 (per sq.ft.) Rate 2023 (per sq.ft.)  Rate 2024 (per sq.ft.)  \
# 0                  19885                  18681                   20138
# 1                  28632                  30545                   32100
# 2                  25576                  23887                   25103
# 3                  54140                  51208                   54346
# 4                  57170                  59357                   51011
#
#    Rate 2025 (per sq.ft.)
# 0                 21381.6
# 1                 27342.0
# 2                 26906.0
# 3                 57346.0
# 4                 52827.0
#
# [5 rows x 29 columns]

# %%
df.shape
# Out:
# (10000, 29)

# %%
df.nunique()
# Out:
# ID                                        10000
# Property Type                                 1
# Address Area                                 11
# Amenities                                   509
# Property Age                                 14
# Carpet Area (sq.ft.)                       2217
# Super Buildup Rate (per sq.ft.)            9034
# Built-Up Area (sq.ft.)                     2288
# Area as per Approved Plan (sq.ft.)         2304
# Valuation Area (sq.ft.)                    2288
# Super Built-up Area (sq.ft.)               2457
# Total Value (INR)                          9996
# No of Car Parks                               3
# Value of Car Park (INR)                       3
# Final Value by Comparison Method (INR)     9999
# Configuration                                 6
# Condition                                     4
# Landmark                                      6
# Landmark Distance (KM)                       46
# Last Sale Price (per sq.ft.)               9156
# Last to Last Sale Price (per sq.ft.)       9188
# Last Sale Year                               14
# Last to Last Sale Year                       14
# Property Name                              1006
# Rate 2021 (per sq.ft.)                     8991
# Rate 2022 (per sq.ft.)                     9071
# Rate 2023 (per sq.ft.)                     9068
# Rate 2024 (per sq.ft.)                     9069
# Rate 2025 (per sq.ft.)                     9034
# dtype: int64

# %% [markdown]
# - Property Type has 1 single value for all the records.

# %%
df.isnull().sum()
# Out:
# ID                                        0
# Property Type                             0
# Address Area                              0
# Amenities                                 0
# Property Age                              0
# Carpet Area (sq.ft.)                      0
# Super Buildup Rate (per sq.ft.)           0
# Built-Up Area (sq.ft.)                    0
# Area as per Approved Plan (sq.ft.)        0
# Valuation Area (sq.ft.)                   0
# Super Built-up Area (sq.ft.)              0
# Total Value (INR)                         0
# No of Car Parks                           0
# Value of Car Park (INR)                   0
# Final Value by Comparison Method (INR)    0
# Configuration                             0
# Condition                                 0
# Landmark                                  0
# Landmark Distance (KM)                    0
# Last Sale Price (per sq.ft.)              0
# Last to Last Sale Price (per sq.ft.)      0
# Last Sale Year                            0
# Last to Last Sale Year                    0
# Property Name                             0
# Rate 2021 (per sq.ft.)                    0
# Rate 2022 (per sq.ft.)                    0
# Rate 2023 (per sq.ft.)                    0
# Rate 2024 (per sq.ft.)                    0
# Rate 2025 (per sq.ft.)                    0
# dtype: int64

# %% [markdown]
# - data is highly cleaned and contains no null values

# %%
df.dtypes
# Out:
# ID                                          int64
# Property Type                              object
# Address Area                               object
# Amenities                                  object
# Property Age                                int64
# Carpet Area (sq.ft.)                        int64
# Super Buildup Rate (per sq.ft.)           float64
# Built-Up Area (sq.ft.)                      int64
# Area as per Approved Plan (sq.ft.)          int64
# Valuation Area (sq.ft.)                     int64
# Super Built-up Area (sq.ft.)                int64
# Total Value (INR)                         float64
# No of Car Parks                             int64
# Value of Car Park (INR)                     int64
# Final Value by Comparison Method (INR)    float64
# Configuration                              object
# Condition                                  object
# Landmark                                   object
# Landmark Distance (KM)                    float64
# Last Sale Price (per sq.ft.)                int64
# Last to Last Sale Price (per sq.ft.)        int64
# Last Sale Year                              int64
# Last to Last Sale Year                      int64
# Property Name                              object
# Rate 2021 (per sq.ft.)                      int64
# Rate 2022 (per sq.ft.)                      int64
# Rate 2023 (per sq.ft.)                      int64
# Rate 2024 (per sq.ft.)                      int64
# Rate 2025 (per sq.ft.)                    float64
# dtype: object

# %%
df.describe().T
# Out:
#                                           count          mean           std  \
# ID                                      10000.0  5.000500e+03  2.886896e+03
# Property Age                            10000.0  8.470000e+00  4.006658e+00
# Carpet Area (sq.ft.)                    10000.0  1.839297e+03  8.361042e+02
# Super Buildup Rate (per sq.ft.)         10000.0  4.340103e+04  1.978112e+04
# Built-Up Area (sq.ft.)                  10000.0  1.804347e+03  8.361748e+02
# Area as per Approved Plan (sq.ft.)      10000.0  1.784404e+03  8.362242e+02
# Valuation Area (sq.ft.)                 10000.0  1.804347e+03  8.361748e+02
# Super Built-up Area (sq.ft.)            10000.0  1.989247e+03  8.367105e+02
# Total Value (INR)                       10000.0  8.716170e+07  7.307742e+07
# No of Car Parks                         10000.0  1.991500e+00  8.172482e-01
# Value of Car Park (INR)                 10000.0  9.957500e+05  4.086241e+05
# Final Value by Comparison Method (INR)  10000.0  8.815745e+07  7.307988e+07
# Landmark Distance (KM)                  10000.0  2.753550e+00  1.298240e+00
# Last Sale Price (per sq.ft.)            10000.0  4.366871e+04  2.084149e+04
# Last to Last Sale Price (per sq.ft.)    10000.0  4.371658e+04  2.111723e+04
# Last Sale Year                          10000.0  2.020796e+03  3.150673e+00
# Last to Last Sale Year                  10000.0  2.018800e+03  3.543258e+00
# Rate 2021 (per sq.ft.)                  10000.0  4.114707e+04  1.886653e+04
# Rate 2022 (per sq.ft.)                  10000.0  4.178687e+04  1.935632e+04
# Rate 2023 (per sq.ft.)                  10000.0  4.236313e+04  1.970303e+04
# Rate 2024 (per sq.ft.)                  10000.0  4.293902e+04  1.991774e+04
# Rate 2025 (per sq.ft.)                  10000.0  4.340103e+04  1.978112e+04
#
#                                               min          25%         50%  \
# ID                                            1.0      2500.75      5000.5
# Property Age                                  2.0         5.00         8.0
# Carpet Area (sq.ft.)                        450.0      1149.00      2002.0
# Super Buildup Rate (per sq.ft.)           19920.8     28271.00     38963.0
# Built-Up Area (sq.ft.)                      401.0      1113.00      1960.5
# Area as per Approved Plan (sq.ft.)          376.0      1093.00      1936.5
# Valuation Area (sq.ft.)                     401.0      1113.00      1960.5
# Super Built-up Area (sq.ft.)                551.0      1298.00      2118.0
# Total Value (INR)                       8364347.2  33217127.50  61696140.0
# No of Car Parks                               1.0         1.00         2.0
# Value of Car Park (INR)                  500000.0    500000.00   1000000.0
# Final Value by Comparison Method (INR)  9513680.0  34112137.00  62648002.4
# Landmark Distance (KM)                        0.5         1.60         2.7
# Last Sale Price (per sq.ft.)              11080.0     28139.00     38412.5
# Last to Last Sale Price (per sq.ft.)      11080.0     28208.00     38387.5
# Last Sale Year                             2011.0      2019.00      2022.0
# Last to Last Sale Year                     2011.0      2016.00      2019.0
# Rate 2021 (per sq.ft.)                    17533.0     26629.75     36754.5
# Rate 2022 (per sq.ft.)                    16447.0     27351.75     37274.5
# Rate 2023 (per sq.ft.)                    17457.0     27429.00     37416.5
# Rate 2024 (per sq.ft.)                    18519.0     27634.50     37809.0
# Rate 2025 (per sq.ft.)                    19920.8     28271.00     38963.0
#
#                                                  75%          max
# ID                                      7.500250e+03      10000.0
# Property Age                            1.200000e+01         15.0
# Carpet Area (sq.ft.)                    2.493250e+03       3500.0
# Super Buildup Rate (per sq.ft.)         5.321800e+04     118204.0
# Built-Up Area (sq.ft.)                  2.459250e+03       3468.0
# Area as per Approved Plan (sq.ft.)      2.439000e+03       3450.0
# Valuation Area (sq.ft.)                 2.459250e+03       3468.0
# Super Built-up Area (sq.ft.)            2.647000e+03       3698.0
# Total Value (INR)                       1.205506e+08  403603928.0
# No of Car Parks                         3.000000e+00          3.0
# Value of Car Park (INR)                 1.500000e+06    1500000.0
# Final Value by Comparison Method (INR)  1.216377e+08  404103928.0
# Landmark Distance (KM)                  3.900000e+00          5.0
# Last Sale Price (per sq.ft.)            5.372275e+04     159916.0
# Last to Last Sale Price (per sq.ft.)    5.387700e+04     159916.0
# Last Sale Year                          2.023000e+03       2024.0
# Last to Last Sale Year                  2.022000e+03       2024.0
# Rate 2021 (per sq.ft.)                  5.070575e+04     119699.0
# Rate 2022 (per sq.ft.)                  5.104800e+04     124595.0
# Rate 2023 (per sq.ft.)                  5.141350e+04     130293.0
# Rate 2024 (per sq.ft.)                  5.243650e+04     133196.0
# Rate 2025 (per sq.ft.)                  5.321800e+04     118204.0

# %%
df.describe(include='object').T
# Out:
#                count unique                    top   freq
# Property Type  10000      1            Residential  10000
# Address Area   10000     11         Santacruz West    966
# Amenities      10000    509  Garden, Swimming Pool    133
# Configuration  10000      6                   4BHK   1718
# Condition      10000      4                   Fair   3568
# Landmark       10000      6                  Hotel   1713
# Property Name  10000   1006    Santacruz West Twrs     43

# %% [markdown]
# - property type should be removed.
# - property name remove or not ?
# - condition,configuration convert into numeric val
# - landmark one hot encode
# - amenities needs attention

# %%
sns.histplot(df['Super Built-up Area (sq.ft.)'], bins=50, kde=True)
plt.show()

# %%
sns.histplot(df['Carpet Area (sq.ft.)'], bins=50, kde=True)
plt.show()

# %% [markdown]
# -> carpet area and super buildup both are related with each other, and from the plots we observed that they follow same trend.

# %%
sns.histplot(df['Total Value (INR)'], bins=50, kde=True)
plt.show()

# %% [markdown]
# -> Data is skewed but not imbalance

# %%
sns.histplot(df['Property Age'], bins=50, kde=True)
plt.show()

# %% [markdown]
# -> property age is also distibuted

# %%
sns.boxplot(x=df['Super Built-up Area (sq.ft.)'])
plt.show()

# %% [markdown]
# -> No outliers in target variable

# %%
numerical_df = df.select_dtypes(include=['number'])
numerical_df.head()
# Out:
#    ID  Property Age  Carpet Area (sq.ft.)  Super Buildup Rate (per sq.ft.)  \
# 0   1            15                   709                          21381.6
# 1   2             6                  1110                          27342.0
# 2   3            10                  1130                          26906.0
# 3   4             8                  2166                          57346.0
# 4   5             3                  2453                          52827.0
#
#    Built-Up Area (sq.ft.)  Area as per Approved Plan (sq.ft.)  \
# 0                     672                                 643
# 1                    1089                                1067
# 2                    1102                                1072
# 3                    2120                                2096
# 4                    2419                                2403
#
#    Valuation Area (sq.ft.)  Super Built-up Area (sq.ft.)  Total Value (INR)  \
# 0                      672                           811         14368435.2
# 1                     1089                          1228         29775438.0
# 2                     1102                          1298         29650412.0
# 3                     2120                          2300        121573520.0
# 4                     2419                          2649        127788513.0
#
#    No of Car Parks  ...  Landmark Distance (KM)  Last Sale Price (per sq.ft.)  \
# 0                2  ...                     1.1                         35606
# 1                2  ...                     4.8                         32697
# 2                2  ...                     3.8                         24754
# 3                3  ...                     1.2                         53333
# 4                1  ...                     1.1                         52791
#
#    Last to Last Sale Price (per sq.ft.)  Last Sale Year  \
# 0                                 35606            2011
# 1                                 32697            2020
# 2                                 24754            2016
# 3                                 49114            2020
# 4                                 52791            2023
#
#    Last to Last Sale Year  Rate 2021 (per sq.ft.)  Rate 2022 (per sq.ft.)  \
# 0                    2011                   18570                   19885
# 1                    2020                   27538                   28632
# 2                    2016                   24236                   25576
# 3                    2018                   50907                   54140
# 4                    2023                   54514                   57170
#
#    Rate 2023 (per sq.ft.)  Rate 2024 (per sq.ft.)  Rate 2025 (per sq.ft.)
# 0                   18681                   20138                 21381.6
# 1                   30545                   32100                 27342.0
# 2                   23887                   25103                 26906.0
# 3                   51208                   54346                 57346.0
# 4                   59357                   51011                 52827.0
#
# [5 rows x 22 columns]

# %%
numerical_df.corr()
# Out:
#                                               ID  Property Age  \
# ID                                      1.000000      0.013467
# Property Age                            0.013467      1.000000
# Carpet Area (sq.ft.)                   -0.017001     -0.001978
# Super Buildup Rate (per sq.ft.)        -0.012296     -0.199626
# Built-Up Area (sq.ft.)                 -0.017054     -0.001966
# Area as per Approved Plan (sq.ft.)     -0.017099     -0.001994
# Valuation Area (sq.ft.)                -0.017054     -0.001966
# Super Built-up Area (sq.ft.)           -0.017115     -0.001847
# Total Value (INR)                      -0.015598     -0.109672
# No of Car Parks                         0.013583      0.020004
# Value of Car Park (INR)                 0.013583      0.020004
# Final Value by Comparison Method (INR) -0.015522     -0.109556
# Landmark Distance (KM)                  0.002085      0.008226
# Last Sale Price (per sq.ft.)           -0.009168     -0.177115
# Last to Last Sale Price (per sq.ft.)   -0.008143     -0.173690
# Last Sale Year                         -0.016555     -0.636044
# Last to Last Sale Year                 -0.014215     -0.871741
# Rate 2021 (per sq.ft.)                 -0.012044     -0.200016
# Rate 2022 (per sq.ft.)                 -0.011871     -0.198063
# Rate 2023 (per sq.ft.)                 -0.012277     -0.197923
# Rate 2024 (per sq.ft.)                 -0.011638     -0.197013
# Rate 2025 (per sq.ft.)                 -0.012296     -0.199626
#
#                                         Carpet Area (sq.ft.)  \
# ID                                                 -0.017001
# Property Age                                       -0.001978
# Carpet Area (sq.ft.)                                1.000000
# Super Buildup Rate (per sq.ft.)                     0.535390
# Built-Up Area (sq.ft.)                              0.999943
# Area as per Approved Plan (sq.ft.)                  0.999917
# Valuation Area (sq.ft.)                             0.999943
# Super Built-up Area (sq.ft.)                        0.999395
# Total Value (INR)                                   0.813991
# No of Car Parks                                     0.004799
# Value of Car Park (INR)                             0.004799
# Final Value by Comparison Method (INR)              0.813990
# Landmark Distance (KM)                             -0.006587
# Last Sale Price (per sq.ft.)                        0.509351
# Last to Last Sale Price (per sq.ft.)                0.501162
# Last Sale Year                                     -0.014213
# Last to Last Sale Year                             -0.008774
# Rate 2021 (per sq.ft.)                              0.532284
# Rate 2022 (per sq.ft.)                              0.526575
# Rate 2023 (per sq.ft.)                              0.525825
# Rate 2024 (per sq.ft.)                              0.526071
# Rate 2025 (per sq.ft.)                              0.535390
#
#                                         Super Buildup Rate (per sq.ft.)  \
# ID                                                            -0.012296
# Property Age                                                  -0.199626
# Carpet Area (sq.ft.)                                           0.535390
# Super Buildup Rate (per sq.ft.)                                1.000000
# Built-Up Area (sq.ft.)                                         0.535177
# Area as per Approved Plan (sq.ft.)                             0.535208
# Valuation Area (sq.ft.)                                        0.535177
# Super Built-up Area (sq.ft.)                                   0.535129
# Total Value (INR)                                              0.899447
# No of Car Parks                                               -0.001381
# Value of Car Park (INR)                                       -0.001381
# Final Value by Comparison Method (INR)                         0.899409
# Landmark Distance (KM)                                        -0.015671
# Last Sale Price (per sq.ft.)                                   0.944749
# Last to Last Sale Price (per sq.ft.)                           0.930604
# Last Sale Year                                                 0.123246
# Last to Last Sale Year                                         0.169126
# Rate 2021 (per sq.ft.)                                         0.995376
# Rate 2022 (per sq.ft.)                                         0.983738
# Rate 2023 (per sq.ft.)                                         0.979741
# Rate 2024 (per sq.ft.)                                         0.984063
# Rate 2025 (per sq.ft.)                                         1.000000
#
#                                         Built-Up Area (sq.ft.)  \
# ID                                                   -0.017054
# Property Age                                         -0.001966
# Carpet Area (sq.ft.)                                  0.999943
# Super Buildup Rate (per sq.ft.)                       0.535177
# Built-Up Area (sq.ft.)                                1.000000
# Area as per Approved Plan (sq.ft.)                    0.999974
# Valuation Area (sq.ft.)                               1.000000
# Super Built-up Area (sq.ft.)                          0.999333
# Total Value (INR)                                     0.813901
# No of Car Parks                                       0.005027
# Value of Car Park (INR)                               0.005027
# Final Value by Comparison Method (INR)                0.813902
# Landmark Distance (KM)                               -0.006755
# Last Sale Price (per sq.ft.)                          0.509208
# Last to Last Sale Price (per sq.ft.)                  0.501037
# Last Sale Year                                       -0.014159
# Last to Last Sale Year                               -0.008835
# Rate 2021 (per sq.ft.)                                0.532083
# Rate 2022 (per sq.ft.)                                0.526388
# Rate 2023 (per sq.ft.)                                0.525625
# Rate 2024 (per sq.ft.)                                0.525872
# Rate 2025 (per sq.ft.)                                0.535177
#
#                                         Area as per Approved Plan (sq.ft.)  \
# ID                                                               -0.017099
# Property Age                                                     -0.001994
# Carpet Area (sq.ft.)                                              0.999917
# Super Buildup Rate (per sq.ft.)                                   0.535208
# Built-Up Area (sq.ft.)                                            0.999974
# Area as per Approved Plan (sq.ft.)                                1.000000
# Valuation Area (sq.ft.)                                           0.999974
# Super Built-up Area (sq.ft.)                                      0.999307
# Total Value (INR)                                                 0.813873
# No of Car Parks                                                   0.004996
# Value of Car Park (INR)                                           0.004996
# Final Value by Comparison Method (INR)                            0.813873
# Landmark Distance (KM)                                           -0.006836
# Last Sale Price (per sq.ft.)                                      0.509220
# Last to Last Sale Price (per sq.ft.)                              0.501063
# Last Sale Year                                                   -0.014062
# Last to Last Sale Year                                           -0.008756
# Rate 2021 (per sq.ft.)                                            0.532118
# Rate 2022 (per sq.ft.)                                            0.526412
# Rate 2023 (per sq.ft.)                                            0.525667
# Rate 2024 (per sq.ft.)                                            0.525912
# Rate 2025 (per sq.ft.)                                            0.535208
#
#                                         Valuation Area (sq.ft.)  \
# ID                                                    -0.017054
# Property Age                                          -0.001966
# Carpet Area (sq.ft.)                                   0.999943
# Super Buildup Rate (per sq.ft.)                        0.535177
# Built-Up Area (sq.ft.)                                 1.000000
# Area as per Approved Plan (sq.ft.)                     0.999974
# Valuation Area (sq.ft.)                                1.000000
# Super Built-up Area (sq.ft.)                           0.999333
# Total Value (INR)                                      0.813901
# No of Car Parks                                        0.005027
# Value of Car Park (INR)                                0.005027
# Final Value by Comparison Method (INR)                 0.813902
# Landmark Distance (KM)                                -0.006755
# Last Sale Price (per sq.ft.)                           0.509208
# Last to Last Sale Price (per sq.ft.)                   0.501037
# Last Sale Year                                        -0.014159
# Last to Last Sale Year                                -0.008835
# Rate 2021 (per sq.ft.)                                 0.532083
# Rate 2022 (per sq.ft.)                                 0.526388
# Rate 2023 (per sq.ft.)                                 0.525625
# Rate 2024 (per sq.ft.)                                 0.525872
# Rate 2025 (per sq.ft.)                                 0.535177
#
#                                         Super Built-up Area (sq.ft.)  \
# ID                                                         -0.017115
# Property Age                                               -0.001847
# Carpet Area (sq.ft.)                                        0.999395
# Super Buildup Rate (per sq.ft.)                             0.535129
# Built-Up Area (sq.ft.)                                      0.999333
# Area as per Approved Plan (sq.ft.)                          0.999307
# Valuation Area (sq.ft.)                                     0.999333
# Super Built-up Area (sq.ft.)                                1.000000
# Total Value (INR)                                           0.813564
# No of Car Parks                                             0.003849
# Value of Car Park (INR)                                     0.003849
# Final Value by Comparison Method (INR)                      0.813558
# Landmark Distance (KM)                                     -0.006180
# Last Sale Price (per sq.ft.)                                0.509012
# Last to Last Sale Price (per sq.ft.)                        0.500886
# Last Sale Year                                             -0.014395
# Last to Last Sale Year                                     -0.008830
# Rate 2021 (per sq.ft.)                                      0.531995
# Rate 2022 (per sq.ft.)                                      0.526340
# Rate 2023 (per sq.ft.)                                      0.525606
# Rate 2024 (per sq.ft.)                                      0.525854
# Rate 2025 (per sq.ft.)                                      0.535129
#
#                                         Total Value (INR)  No of Car Parks  \
# ID                                              -0.015598         0.013583
# Property Age                                    -0.109672         0.020004
# Carpet Area (sq.ft.)                             0.813991         0.004799
# Super Buildup Rate (per sq.ft.)                  0.899447        -0.001381
# Built-Up Area (sq.ft.)                           0.813901         0.005027
# Area as per Approved Plan (sq.ft.)               0.813873         0.004996
# Valuation Area (sq.ft.)                          0.813901         0.005027
# Super Built-up Area (sq.ft.)                     0.813564         0.003849
# Total Value (INR)                                1.000000         0.003237
# No of Car Parks                                  0.003237         1.000000
# Value of Car Park (INR)                          0.003237         1.000000
# Final Value by Comparison Method (INR)           0.999984         0.008829
# Landmark Distance (KM)                          -0.013024         0.003172
# Last Sale Price (per sq.ft.)                     0.850810        -0.004835
# Last to Last Sale Price (per sq.ft.)             0.837307        -0.004955
# Last Sale Year                                   0.062265        -0.018422
# Last to Last Sale Year                           0.087488        -0.016128
# Rate 2021 (per sq.ft.)                           0.895127         0.000688
# Rate 2022 (per sq.ft.)                           0.884693         0.000120
# Rate 2023 (per sq.ft.)                           0.881964        -0.003431
# Rate 2024 (per sq.ft.)                           0.885017        -0.003398
# Rate 2025 (per sq.ft.)                           0.899447        -0.001381
#
#                                         ...  Landmark Distance (KM)  \
# ID                                      ...                0.002085
# Property Age                            ...                0.008226
# Carpet Area (sq.ft.)                    ...               -0.006587
# Super Buildup Rate (per sq.ft.)         ...               -0.015671
# Built-Up Area (sq.ft.)                  ...               -0.006755
# Area as per Approved Plan (sq.ft.)      ...               -0.006836
# Valuation Area (sq.ft.)                 ...               -0.006755
# Super Built-up Area (sq.ft.)            ...               -0.006180
# Total Value (INR)                       ...               -0.013024
# No of Car Parks                         ...                0.003172
# Value of Car Park (INR)                 ...                0.003172
# Final Value by Comparison Method (INR)  ...               -0.013006
# Landmark Distance (KM)                  ...                1.000000
# Last Sale Price (per sq.ft.)            ...               -0.016518
# Last to Last Sale Price (per sq.ft.)    ...               -0.017014
# Last Sale Year                          ...               -0.000894
# Last to Last Sale Year                  ...               -0.001282
# Rate 2021 (per sq.ft.)                  ...               -0.015907
# Rate 2022 (per sq.ft.)                  ...               -0.016998
# Rate 2023 (per sq.ft.)                  ...               -0.014877
# Rate 2024 (per sq.ft.)                  ...               -0.014907
# Rate 2025 (per sq.ft.)                  ...               -0.015671
#
#                                         Last Sale Price (per sq.ft.)  \
# ID                                                         -0.009168
# Property Age                                               -0.177115
# Carpet Area (sq.ft.)                                        0.509351
# Super Buildup Rate (per sq.ft.)                             0.944749
# Built-Up Area (sq.ft.)                                      0.509208
# Area as per Approved Plan (sq.ft.)                          0.509220
# Valuation Area (sq.ft.)                                     0.509208
# Super Built-up Area (sq.ft.)                                0.509012
# Total Value (INR)                                           0.850810
# No of Car Parks                                            -0.004835
# Value of Car Park (INR)                                    -0.004835
# Final Value by Comparison Method (INR)                      0.850754
# Landmark Distance (KM)                                     -0.016518
# Last Sale Price (per sq.ft.)                                1.000000
# Last to Last Sale Price (per sq.ft.)                        0.984987
# Last Sale Year                                              0.097111
# Last to Last Sale Year                                      0.144472
# Rate 2021 (per sq.ft.)                                      0.940159
# Rate 2022 (per sq.ft.)                                      0.929759
# Rate 2023 (per sq.ft.)                                      0.926380
# Rate 2024 (per sq.ft.)                                      0.929932
# Rate 2025 (per sq.ft.)                                      0.944749
#
#                                         Last to Last Sale Price (per sq.ft.)  \
# ID                                                                 -0.008143
# Property Age                                                       -0.173690
# Carpet Area (sq.ft.)                                                0.501162
# Super Buildup Rate (per sq.ft.)                                     0.930604
# Built-Up Area (sq.ft.)                                              0.501037
# Area as per Approved Plan (sq.ft.)                                  0.501063
# Valuation Area (sq.ft.)                                             0.501037
# Super Built-up Area (sq.ft.)                                        0.500886
# Total Value (INR)                                                   0.837307
# No of Car Parks                                                    -0.004955
# Value of Car Park (INR)                                            -0.004955
# Final Value by Comparison Method (INR)                              0.837251
# Landmark Distance (KM)                                             -0.017014
# Last Sale Price (per sq.ft.)                                        0.984987
# Last to Last Sale Price (per sq.ft.)                                1.000000
# Last Sale Year                                                      0.096279
# Last to Last Sale Year                                              0.140517
# Rate 2021 (per sq.ft.)                                              0.926386
# Rate 2022 (per sq.ft.)                                              0.916408
# Rate 2023 (per sq.ft.)                                              0.912744
# Rate 2024 (per sq.ft.)                                              0.916018
# Rate 2025 (per sq.ft.)                                              0.930604
#
#                                         Last Sale Year  \
# ID                                           -0.016555
# Property Age                                 -0.636044
# Carpet Area (sq.ft.)                         -0.014213
# Super Buildup Rate (per sq.ft.)               0.123246
# Built-Up Area (sq.ft.)                       -0.014159
# Area as per Approved Plan (sq.ft.)           -0.014062
# Valuation Area (sq.ft.)                      -0.014159
# Super Built-up Area (sq.ft.)                 -0.014395
# Total Value (INR)                             0.062265
# No of Car Parks                              -0.018422
# Value of Car Park (INR)                      -0.018422
# Final Value by Comparison Method (INR)        0.062160
# Landmark Distance (KM)                       -0.000894
# Last Sale Price (per sq.ft.)                  0.097111
# Last to Last Sale Price (per sq.ft.)          0.096279
# Last Sale Year                                1.000000
# Last to Last Sale Year                        0.806299
# Rate 2021 (per sq.ft.)                        0.122708
# Rate 2022 (per sq.ft.)                        0.119630
# Rate 2023 (per sq.ft.)                        0.118635
# Rate 2024 (per sq.ft.)                        0.120608
# Rate 2025 (per sq.ft.)                        0.123246
#
#                                         Last to Last Sale Year  \
# ID                                                   -0.014215
# Property Age                                         -0.871741
# Carpet Area (sq.ft.)                                 -0.008774
# Super Buildup Rate (per sq.ft.)                       0.169126
# Built-Up Area (sq.ft.)                               -0.008835
# Area as per Approved Plan (sq.ft.)                   -0.008756
# Valuation Area (sq.ft.)                              -0.008835
# Super Built-up Area (sq.ft.)                         -0.008830
# Total Value (INR)                                     0.087488
# No of Car Parks                                      -0.016128
# Value of Car Park (INR)                              -0.016128
# Final Value by Comparison Method (INR)                0.087395
# Landmark Distance (KM)                               -0.001282
# Last Sale Price (per sq.ft.)                          0.144472
# Last to Last Sale Price (per sq.ft.)                  0.140517
# Last Sale Year                                        0.806299
# Last to Last Sale Year                                1.000000
# Rate 2021 (per sq.ft.)                                0.169093
# Rate 2022 (per sq.ft.)                                0.167312
# Rate 2023 (per sq.ft.)                                0.166584
# Rate 2024 (per sq.ft.)                                0.166682
# Rate 2025 (per sq.ft.)                                0.169126
#
#                                         Rate 2021 (per sq.ft.)  \
# ID                                                   -0.012044
# Property Age                                         -0.200016
# Carpet Area (sq.ft.)                                  0.532284
# Super Buildup Rate (per sq.ft.)                       0.995376
# Built-Up Area (sq.ft.)                                0.532083
# Area as per Approved Plan (sq.ft.)                    0.532118
# Valuation Area (sq.ft.)                               0.532083
# Super Built-up Area (sq.ft.)                          0.531995
# Total Value (INR)                                     0.895127
# No of Car Parks                                       0.000688
# Value of Car Park (INR)                               0.000688
# Final Value by Comparison Method (INR)                0.895100
# Landmark Distance (KM)                               -0.015907
# Last Sale Price (per sq.ft.)                          0.940159
# Last to Last Sale Price (per sq.ft.)                  0.926386
# Last Sale Year                                        0.122708
# Last to Last Sale Year                                0.169093
# Rate 2021 (per sq.ft.)                                1.000000
# Rate 2022 (per sq.ft.)                                0.986206
# Rate 2023 (per sq.ft.)                                0.979899
# Rate 2024 (per sq.ft.)                                0.981921
# Rate 2025 (per sq.ft.)                                0.995376
#
#                                         Rate 2022 (per sq.ft.)  \
# ID                                                   -0.011871
# Property Age                                         -0.198063
# Carpet Area (sq.ft.)                                  0.526575
# Super Buildup Rate (per sq.ft.)                       0.983738
# Built-Up Area (sq.ft.)                                0.526388
# Area as per Approved Plan (sq.ft.)                    0.526412
# Valuation Area (sq.ft.)                               0.526388
# Super Built-up Area (sq.ft.)                          0.526340
# Total Value (INR)                                     0.884693
# No of Car Parks                                       0.000120
# Value of Car Park (INR)                               0.000120
# Final Value by Comparison Method (INR)                0.884664
# Landmark Distance (KM)                               -0.016998
# Last Sale Price (per sq.ft.)                          0.929759
# Last to Last Sale Price (per sq.ft.)                  0.916408
# Last Sale Year                                        0.119630
# Last to Last Sale Year                                0.167312
# Rate 2021 (per sq.ft.)                                0.986206
# Rate 2022 (per sq.ft.)                                1.000000
# Rate 2023 (per sq.ft.)                                0.985721
# Rate 2024 (per sq.ft.)                                0.979573
# Rate 2025 (per sq.ft.)                                0.983738
#
#                                         Rate 2023 (per sq.ft.)  \
# ID                                                   -0.012277
# Property Age                                         -0.197923
# Carpet Area (sq.ft.)                                  0.525825
# Super Buildup Rate (per sq.ft.)                       0.979741
# Built-Up Area (sq.ft.)                                0.525625
# Area as per Approved Plan (sq.ft.)                    0.525667
# Valuation Area (sq.ft.)                               0.525625
# Super Built-up Area (sq.ft.)                          0.525606
# Total Value (INR)                                     0.881964
# No of Car Parks                                      -0.003431
# Value of Car Park (INR)                              -0.003431
# Final Value by Comparison Method (INR)                0.881915
# Landmark Distance (KM)                               -0.014877
# Last Sale Price (per sq.ft.)                          0.926380
# Last to Last Sale Price (per sq.ft.)                  0.912744
# Last Sale Year                                        0.118635
# Last to Last Sale Year                                0.166584
# Rate 2021 (per sq.ft.)                                0.979899
# Rate 2022 (per sq.ft.)                                0.985721
# Rate 2023 (per sq.ft.)                                1.000000
# Rate 2024 (per sq.ft.)                                0.985271
# Rate 2025 (per sq.ft.)                                0.979741
#
#                                         Rate 2024 (per sq.ft.)  \
# ID                                                   -0.011638
# Property Age                                         -0.197013
# Carpet Area (sq.ft.)                                  0.526071
# Super Buildup Rate (per sq.ft.)                       0.984063
# Built-Up Area (sq.ft.)                                0.525872
# Area as per Approved Plan (sq.ft.)                    0.525912
# Valuation Area (sq.ft.)                               0.525872
# Super Built-up Area (sq.ft.)                          0.525854
# Total Value (INR)                                     0.885017
# No of Car Parks                                      -0.003398
# Value of Car Park (INR)                              -0.003398
# Final Value by Comparison Method (INR)                0.884968
# Landmark Distance (KM)                               -0.014907
# Last Sale Price (per sq.ft.)                          0.929932
# Last to Last Sale Price (per sq.ft.)                  0.916018
# Last Sale Year                                        0.120608
# Last to Last Sale Year                                0.166682
# Rate 2021 (per sq.ft.)                                0.981921
# Rate 2022 (per sq.ft.)                                0.979573
# Rate 2023 (per sq.ft.)                                0.985271
# Rate 2024 (per sq.ft.)                                1.000000
# Rate 2025 (per sq.ft.)                                0.984063
#
#                                         Rate 2025 (per sq.ft.)
# ID                                                   -0.012296
# Property Age                                         -0.199626
# Carpet Area (sq.ft.)                                  0.535390
# Super Buildup Rate (per sq.ft.)                       1.000000
# Built-Up Area (sq.ft.)                                0.535177
# Area as per Approved Plan (sq.ft.)                    0.535208
# Valuation Area (sq.ft.)                               0.535177
# Super Built-up Area (sq.ft.)                          0.535129
# Total Value (INR)                                     0.899447
# No of Car Parks                                      -0.001381
# Value of Car Park (INR)                              -0.001381
# Final Value by Comparison Method (INR)                0.899409
# Landmark Distance (KM)                               -0.015671
# Last Sale Price (per sq.ft.)                          0.944749
# Last to Last Sale Price (per sq.ft.)                  0.930604
# Last Sale Year                                        0.123246
# Last to Last Sale Year                                0.169126
# Rate 2021 (per sq.ft.)                                0.995376
# Rate 2022 (per sq.ft.)                                0.983738
# Rate 2023 (per sq.ft.)                                0.979741
# Rate 2024 (per sq.ft.)                                0.984063
# Rate 2025 (per sq.ft.)                                1.000000
#
# [22 rows x 22 columns]

# %%
fig=plt.figure(figsize=(15, 10))
sns.heatmap(numerical_df.corr(), annot=True, cmap='coolwarm', fmt=".2f")
plt.show()

# %%
sns.countplot(data=df['Condition'])
plt.show()

# %% [markdown]
# - it can be given ordinal numeric value

# %%
sns.countplot(data=df['Configuration'])
plt.show()

# %% [markdown]
# - similarlly here also , ordinal numeric value can be given

# %%
plt.figure(figsize=(8,6))
sns.scatterplot(x='Carpet Area (sq.ft.)', y='Super Buildup Rate (per sq.ft.)', data=df)
plt.title("Carpet Area vs Super Buildup Rate")
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.scatterplot(x='Landmark Distance (KM)', y='Super Buildup Rate (per sq.ft.)', data=df)
plt.title("Landmark Distance vs Super Buildup Rate")
plt.show()

# %% [markdown]
# - landmark distance relates with the price.

# %%
# Variation across Address Area
plt.figure(figsize=(14,6))
sns.boxplot(x='Address Area', y='Super Buildup Rate (per sq.ft.)', data=df)
plt.xticks(rotation=45)
plt.title('Super Buildup Rate by Address Area')
plt.show()

# Variation across Configuration
plt.figure(figsize=(8,5))
sns.boxplot(x='Configuration', y='Super Buildup Rate (per sq.ft.)', data=df)
plt.title('Super Buildup Rate by Configuration')
plt.show()

# Variation across Condition
plt.figure(figsize=(8,5))
sns.boxplot(x='Condition', y='Super Buildup Rate (per sq.ft.)', data=df)
plt.title('Super Buildup Rate by Condition')
plt.show()

# %% [markdown]
# -> Here the outliers are detected in the first graph but they are unique values can't be removed
#
# -> target rises for penthouse category
#
# -> On the basis of condition few outliears are detected

# %%
# Analyze frequency of amenities
from collections import Counter

# Split amenities and count frequency
amenities_list = df['Amenities'].str.split(', ')
amenities_flat = [item for sublist in amenities_list for item in sublist]
amenity_counts = pd.Series(Counter(amenities_flat)).sort_values(ascending=False)

plt.figure(figsize=(10,6))
sns.barplot(x=amenity_counts.index, y=amenity_counts.values)
plt.xticks(rotation=45)
plt.title('Frequency of Amenities')
plt.ylabel('Count')
plt.xlabel('Amenity')
plt.show()

# Check impact of specific amenities on Super Buildup Rate
# Create binary columns for top amenities
top_amenities = amenity_counts.index[:6]  # Select top 6 amenities for visualization
for amenity in top_amenities:
    df[amenity] = df['Amenities'].apply(lambda x: amenity in x)

plt.figure(figsize=(12,6))
sns.boxplot(data=pd.melt(df, id_vars=['Super Buildup Rate (per sq.ft.)'], value_vars=top_amenities),
            x='variable', y='Super Buildup Rate (per sq.ft.)', hue='value')
plt.title('Impact of Top Amenities on Super Buildup Rate')
plt.xlabel('Amenity')
plt.ylabel('Super Buildup Rate (per sq.ft.)')
plt.legend(title='Amenity Present')
plt.show()

# %% [markdown]
# - the pressence of amenities are affecting the tagret
# - we can multi-hot encode as there are only six amenities in total

# %%
# Plot historical rates (Rate 2021–2025) to visualize trends

rate_cols = ['Rate 2021 (per sq.ft.)', 'Rate 2022 (per sq.ft.)', 'Rate 2023 (per sq.ft.)', 'Rate 2024 (per sq.ft.)', 'Rate 2025 (per sq.ft.)']

# Line plot for average rate per year
avg_rates = df[rate_cols].mean()
plt.figure(figsize=(8,5))
sns.lineplot(x=avg_rates.index, y=avg_rates.values, marker='o')
plt.title('Average Super Buildup Rate Trend (2021–2025)')
plt.ylabel('Average Rate (per sq.ft.)')
plt.xlabel('Year')
plt.xticks(rotation=45)
plt.show()

# Boxplot for distribution of rates per year
df_melted = df.melt(value_vars=rate_cols, var_name='Year', value_name='Rate (per sq.ft.)')
plt.figure(figsize=(10,6))
sns.boxplot(x='Year', y='Rate (per sq.ft.)', data=df_melted)
plt.title('Distribution of Super Buildup Rates by Year')
plt.ylabel('Rate (per sq.ft.)')
plt.xlabel('Year')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# - the rate columns follow a several trend . so we can combine into 1 single columns

# %%
print(df.columns)
# Out:
# Index(['ID', 'Property Type', 'Address Area', 'Amenities', 'Property Age',
#        'Carpet Area (sq.ft.)', 'Super Buildup Rate (per sq.ft.)',
#        'Built-Up Area (sq.ft.)', 'Area as per Approved Plan (sq.ft.)',
#        'Valuation Area (sq.ft.)', 'Super Built-up Area (sq.ft.)',
#        'Total Value (INR)', 'No of Car Parks', 'Value of Car Park (INR)',
#        'Final Value by Comparison Method (INR)', 'Configuration', 'Condition',
#        'Landmark', 'Landmark Distance (KM)', 'Last Sale Price (per sq.ft.)',
#        'Last to Last Sale Price (per sq.ft.)', 'Last Sale Year',
#        'Last to Last Sale Year', 'Property Name', 'Rate 2021 (per sq.ft.)',
#        'Rate 2022 (per sq.ft.)', 'Rate 2023 (per sq.ft.)',
#        'Rate 2024 (per sq.ft.)', 'Rate 2025 (per sq.ft.)', 'Garden', 'Gym',
#        'Playground', 'Swimming Pool', 'Lift', 'Parking'],
#       dtype='object')

# %%
num_df = df[['Carpet Area (sq.ft.)', 'Built-Up Area (sq.ft.)', 'Super Buildup Rate (per sq.ft.)',
             'Valuation Area (sq.ft.)', 'Total Value (INR)', 
             'Final Value by Comparison Method (INR)']].copy()
num_df.head()
# Out:
#    Carpet Area (sq.ft.)  Built-Up Area (sq.ft.)  \
# 0                   709                     672
# 1                  1110                    1089
# 2                  1130                    1102
# 3                  2166                    2120
# 4                  2453                    2419
#
#    Super Buildup Rate (per sq.ft.)  Valuation Area (sq.ft.)  \
# 0                          21381.6                      672
# 1                          27342.0                     1089
# 2                          26906.0                     1102
# 3                          57346.0                     2120
# 4                          52827.0                     2419
#
#    Total Value (INR)  Final Value by Comparison Method (INR)
# 0         14368435.2                              15368435.2
# 1         29775438.0                              30775438.0
# 2         29650412.0                              30650412.0
# 3        121573520.0                             123073520.0
# 4        127788513.0                             128288513.0

# %%
sns.heatmap(num_df.corr(), annot=True, cmap='coolwarm', fmt=".2f")
plt.show()

# %% [markdown]
# -> this are the columns which affects the target most
