# %%
import pymysql

# %%
conn = pymysql.connect(
    host='localhost',
    user='root',
    password='learn@mysql1',
    database='college_db')

# %%
cursor=conn.cursor()

# %%
cursor.execute('SELECT * FROM students;')
rows=cursor.fetchall()
for row in rows:
    print(row)
# Out:
# (101, 'Ravi Kumar', 'Computer Science')
# (102, 'Anjali Sharma', 'Electronics')
# (103, 'Amit Verma', 'Mechanical')
# (104, 'Priya Desai', 'Electrical')
# (105, 'Rajesh Iyer', 'Civil')
# (106, 'Sneha Patel', 'Computer Science')

# %%
data=[(107,'Kuldeep Yadav','AIML'),(108,'Vedant Kalal','AIML')]
cursor.executemany('INSERT INTO students (enr_id,name,branch) VALUES (%s,%s,%s);',data)
# Out:
# 2

# %%
cursor.execute('SELECT * FROM students;')
rows=cursor.fetchall()
for row in rows:
    print(row)
# Out:
# (101, 'Ravi Kumar', 'Computer Science')
# (102, 'Anjali Sharma', 'Electronics')
# (103, 'Amit Verma', 'Mechanical')
# (104, 'Priya Desai', 'Electrical')
# (105, 'Rajesh Iyer', 'Civil')
# (106, 'Sneha Patel', 'Computer Science')
# (107, 'Kuldeep Yadav', 'AIML')
# (108, 'Vedant Kalal', 'AIML')

# %%
cursor.execute("UPDATE students SET name='Kuldeep Kumar' WHERE enr_id=101;")
# Out:
# 1

# %%
cursor.execute('SELECT * FROM students WHERE enr_id=101;')
print(cursor.fetchone())
# Out:
# (101, 'Kuldeep Kumar', 'Computer Science')

# %%
cursor.execute("DELETE FROM students WHERE enr_id=108;")
# Out:
# 1

# %%
cursor.execute('SELECT * FROM students;')
rows=cursor.fetchall()
for row in rows:
    print(row)
# Out:
# (101, 'Kuldeep Kumar', 'Computer Science')
# (102, 'Anjali Sharma', 'Electronics')
# (103, 'Amit Verma', 'Mechanical')
# (104, 'Priya Desai', 'Electrical')
# (105, 'Rajesh Iyer', 'Civil')
# (106, 'Sneha Patel', 'Computer Science')
# (107, 'Kuldeep Yadav', 'AIML')
