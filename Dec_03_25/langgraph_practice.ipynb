# %% [markdown]
# #### This is demo of to add llm in graphs. i am using gemini key.

# %% [markdown]
# `User → LLM Node → Output`

# %%
from langgraph.graph import StateGraph, END
from typing import TypedDict, List
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_core.messages import HumanMessage, AIMessage
from IPython.display import display, Markdown

# %%
# Load API key from .env file
import os
from dotenv import load_dotenv
load_dotenv()

# %%
# Create LLM
llm = ChatGoogleGenerativeAI(model="gemini-1.5-flash")

# %%
# Define Agent State
class AgentState(TypedDict):
    messages: List[str]

# %%
# Define LLM Node
def llm_node(state: AgentState):
    user_message = state["messages"][-1]
    response = llm.generate_content([user_message])
    state["messages"].append(response.text)
    return state

# %%
# ---- GRAPH ----
graph = StateGraph(AgentState)
graph.add_node("llm", llm_node)
graph.set_entry_point("llm")
graph.add_edge("llm", END)

agent = graph.compile()

# %%
# ---- RUN ----
state = {"messages": ["Explain quantum computing in simple words."]}

result = agent.invoke(state)
print(result["messages"][-1])

# %%
from google import genai

client = genai.Client(api_key="AIzaSyCdAA531mUdQfuHO-Hmr0NvWKo6E69Pnvc")

response = client.models.generate_content(
    model="gemini-2.0-flash",
    contents=["Say hi to COOLdeep!"]
)

print(response.text)
# Out:
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# Cell In[5], line 5
#       1 from google import genai
#       3 client = genai.Client(api_key="AIzaSyCdAA531mUdQfuHO-Hmr0NvWKo6E69Pnvc")
# ----> 5 response = client.models.generate_content(
#       6     model="gemini-2.0-flash",
#       7     contents=["Say hi to COOLdeep!"]
#       8 )
#      10 print(response.text)
#
# File e:\SSPL_Internship_Repo\Dec_03_25\venv\Lib\site-packages\google\genai\models.py:5218, in Models.generate_content(self, model, contents, config)
#    5216 while remaining_remote_calls_afc > 0:
#    5217   i += 1
# -> 5218   response = self._generate_content(
#    5219       model=model, contents=contents, config=parsed_config
#    5220   )
#    5222   function_map = _extra_utils.get_function_map(parsed_config)
#    5223   if not function_map:
#
# ...
